# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

# --- Train a scikit-learn model ---
X, y = load_iris(return_X_y=True)
sklearn_model = RandomForestClassifier().fit(X, y)

my_custom_tags = {
    "tag": 0.98,
    "model_type": "RandomForest"
}
sdk.start_run("ANEWRUN")
sdk.register_model(sklearn_model, "MyModel", tags=my_custom_tags)
sdk.end_run()
# Out:
# 2025/11/16 08:02:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# --- [SDK] Finding notebook path to set experiment...
# --- [SDK] Automatically setting experiment to: 'path-16500d19-4e2b-4c19-8446-edcac2d07833' ---
# --- [SDK] Starting run: ANEWRUN (ID: 3a526511b81d4d00b11f3e4557640c11) ---
# Attempting to register model MyModel.
# Detected scikit-learn model.
# 2025/11/16 08:02:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'MyModel' already exists. Creating a new version of this model...
# 2025/11/16 08:02:34 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: MyModel, version 13
# --- [SDK] Manually ending run: ANEWRUN ---
# 🏃 View run ANEWRUN at: http://mlflow-server:5000/#/experiments/63/runs/3a526511b81d4d00b11f3e4557640c11
# 🧪 View experiment at: http://mlflow-server:5000/#/experiments/63
# Created version '13' of model 'MyModel'.

# %%
import ray
print(ray.get(sdk.explorative_take_batch.remote("s3://mybucket/data-delta/", 2)))
# Out:
# (_explorative_take_batch pid=2461) Estimated parquet encoding ratio is 6.463.
# (_explorative_take_batch pid=2461) Estimated parquet reader batch size at 163881 rows
# (_explorative_take_batch pid=2461) A new progress UI is available. To enable, set `ray.data.DataContext.get_current().enable_rich_progress_bars = True`.
# (_explorative_take_batch pid=2461) Registered dataset logger for dataset dataset_9_0
# (_explorative_take_batch pid=2461) Starting execution of Dataset dataset_9_0. Full logs are in /tmp/ray/session_2025-11-15_23-06-51_162506_7/logs/ray-data
# (_explorative_take_batch pid=2461) Execution plan of Dataset dataset_9_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadParquet] -> LimitOperator[limit=2]
# (_explorative_take_batch pid=2461) ⚠️  Ray's object store is configured to use only 42.9% of available memory (11.2GiB out of 26.1GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable.
# {'Table_id': array([3101, 3101], dtype=int32), 'Session_ID': array([1301130618023074711, 1303130623668065976]), 'Interface_ID': array([1, 1], dtype=int32), 'Session_Indicator': array([1, 2], dtype=int32), 'Start_Time_s': array([1754927825, 1754928385]), 'Start_Time_ms': array([690, 121], dtype=int32), 'End_Time_s': array([1754927826, 1754928391]), 'End_Time_ms': array([403, 283], dtype=int32), 'Protocol_Category': array([4, 4], dtype=int32), 'Protocol': array([48000, 48000], dtype=int32), 'Layer_7_Bearer_Protocol': array([0, 0], dtype=int32), 'MSISDN': array([nan, nan]), 'IMSI': array([nan, nan]), 'IMEI': array([nan, nan]), 'Roaming_Type': array([nan,  3.]), 'Roaming_Direction': array([nan,  1.]), 'MS_IP_Address': array(['21.21.62.160', '28.58.95.135'], dtype=object), 'Server_IP_Address': array(['216.239.38.120', '89.44.112.138'], dtype=object), 'MS_Port': array([60066, 50382], dtype=int32), 'Server_Port': array([  443, 14270], dtype=int32), 'APN': array([None, 'MCINET'], dtype=object), 'SGSN_Signaling_Plane_IP_Address': array([None, None], dtype=object), 'GGSN_Signaling_Plane_IP_Address': array([None, None], dtype=object), 'SGSN_User_Plane_IP_Address': array([None, None], dtype=object), 'GGSN_User_Plane_IP_Address': array(['10.155.65.22', '10.185.110.73'], dtype=object), 'MCC': array([None, None], dtype=object), 'MNC': array([None, None], dtype=object), 'RAT': array([1, 1], dtype=int32), 'LAC': array([None, None], dtype=object), 'RAC': array([None, None], dtype=object), 'SAC': array([None, None], dtype=object), 'CI': array([None, None], dtype=object), 'Browser_Type': array([nan, nan]), 'Uplink_Traffic': array([1357,  856]), 'Downlink_Traffic': array([3030, 3827]), 'Network_Uplink_Traffic': array([1821, 1262]), 'Network_Downlink_Traffic': array([3462, 4313]), 'Uplink_Packets': array([8, 7], dtype=int32), 'Downlink_Packets': array([8, 9], dtype=int32), 'TCP_Connection_Status': array([0, 0], dtype=int32), 'TCP_Connection_Release_Status': array([nan, nan]), 'TCP_Connect_RTT_ms': array([7, 7]), 'TCP_Uplink_Out_of_Order_Packets': array([0, 2], dtype=int32), 'TCP_Downlink_Out_of_Order_Packets': array([0, 0], dtype=int32), 'TCP_Uplink_Retransmitted_Packets': array([0, 1], dtype=int32), 'TCP_Downlink_Retransmitted_Packets': array([0, 2], dtype=int32), 'SYN_ACK_Failures_During_TCP_Handshakes': array([0, 0], dtype=int32), 'ACK_Failures_During_TCP_Handshakes': array([0, 0], dtype=int32), 'Host_Name': array(['www.google.com', 'bmi.ir'], dtype=object), 'First_URI_Visited': array(['www.google.com', 'bmi.ir/'], dtype=object), 'Transaction_Type': array([nan,  1.]), 'First_GET_Success_or_Failure_Flag': array([nan, nan]), 'First_GET_Transaction_Failure_Cause_Code': array([nan, nan]), 'First_GET_Response_Delay': array([nan, nan]), 'GET_Transactions': array([nan, nan]), 'Successful_GET_Transactions': array([nan, nan]), 'POST_Transactions': array([nan, nan]), 'Successful_POST_Transactions': array([nan, nan]), 'Page_Browsing_Delay': array([nan, nan]), 'TAC': array([None, None], dtype=object), 'ECI': array([None, None], dtype=object), 'TCP_RTT_of_Step_1_ms': array([2, 2], dtype=int32), 'TCP_Uplink_Retransmitted_Packets_with_Payload': array([0, 0], dtype=int32), 'TCP_Downlink_Retransmitted_Packets_with_Payload': array([0, 0], dtype=int32), 'TCP_Uplink_Packets_with_Payload': array([3, 2], dtype=int32), 'TCP_Downlink_Packets_with_Payload': array([4, 4], dtype=int32), 'RAN_NE_User_Plane_IP_Address': array(['10.3.112.194', '10.155.65.34'], dtype=object), 'First_DNS_Response_Delay_Within_Page_ms': array([186., 404.]), 'First_DNS_Response_Code_Within_Page': array([0, 0], dtype=int32), 'Page_Size': array([2606, 3335], dtype=int32), 'First_Page_Response_Delay_ms': array([nan, nan]), 'MCC_of_Home_Carrier': array([None, '432'], dtype=object), 'MNC_of_Home_Carrier': array([None, '11'], dtype=object), 'User_Agent': array([None,
#        'Mozilla/5.0 (Linux; Android 10; K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.6478.122 Mobile Safa'],
#       dtype=object), 'Uplink_Valid_Data_Transmission_Duration': array([1., 2.]), 'Downlink_Valid_Data_Transmission_Duration': array([ 8., 27.]), 'Device_Window_Size_Calculations': array([4, 1], dtype=int32), 'Device_Side_Small_Window_Times': array([7, 0], dtype=int32), 'Delay_Between_First_TCP_and_First_GET_ms': array([ 820, 2723], dtype=int32), 'Delay_Between_First_GET_ACK_and_First_Data_Packet_ms': array([ 97, 361], dtype=int32), 'Average_Uplink_RTT': array([33,  5], dtype=int32), 'Average_Downlink_RTT': array([  69, 3265], dtype=int32), 'Number_of_Timer_Average_Uplink_RTT_Is_Longer_Than_500_ms': array([0, 0], dtype=int32), 'Number_of_Timer_Average_Downlink_RTT_Is_Longer_Than_1s': array([0, 0], dtype=int32), 'Uplink_RTT_Calculations': array([4, 3], dtype=int32), 'Downlink_RTT_Calculations': array([3, 1], dtype=int32), 'User_Side_Uplink_Lost_Packets': array([0, 0], dtype=int32), 'Server_Side_Uplink_Lost_Packets': array([0, 0], dtype=int32), 'Server_Side_Downlink_Lost_Packets': array([0, 0], dtype=int32), 'User_Side_Downlink_Lost_Packets': array([0, 0], dtype=int32), 'Downlink_TCP_Send_Window_Average_Size': array([ 9108, 22058], dtype=int32), 'Total_Downlink_TCP_Send_Window_Size_Calculations': array([2, 2], dtype=int32), 'Downlink_Maximum_TCP_Send_Window_Size': array([65535, 65160], dtype=int32), 'Total_Uplink_TCP_Send_Window_Average_Size': array([ 8425, 20195], dtype=int32), 'Total_Uplink_TCP_Send_Window_Size_Calculations': array([4, 1], dtype=int32), 'Uplink_Maximum_TCP_Send_Window_Size': array([65535, 65535], dtype=int32), 'Downlink_Continuous_Retransmission_Delay': array([0, 0]), 'User_Side_Hungry_Delay': array([  12, 2723]), 'Server_Side_Hunger_Delay': array([ 155, 2885]), 'Signaling_Consumption_Flag_Signaling_Messages': array([0, 0], dtype=int32), 'First_RAT': array([nan,  0.]), 'Probe_Protocol': array([48001, 48001], dtype=int32), 'Visit_Type': array([3665, 3665], dtype=int32), 'Uplink_Valid_Traffic': array([933, 468]), 'Time_Zone': array([ nan, 210.]), 'DST_Offset': array([nan, nan]), 'Negotiated_Allocation_Retention_Priority': array([nan, nan]), 'Allowed_Uplink_Maximum_Bit_Rate': array([nan, nan]), 'Allowed_Downlink_Maximum_Bit_Rate': array([nan, nan]), 'Negotiated_Traffic_Class': array([nan, nan]), 'Negotiated_Handling_Traffic_Priority': array([nan, nan]), 'Negotiated_QoS_Class_Identifier': array([nan, nan]), 'Total_TCP_Connect_RTT_ms': array([  70, 3277]), 'Total_TCP_RTT_of_Step_1_ms': array([36, 11]), 'APP_ID': array(['48001', '48001'], dtype=object), 'probe_ID': array(['13', '13'], dtype=object), 'Record_type': array(['0', '0'], dtype=object), 'TCP_Uplink_Payload_Traffic': array(['933', '468'], dtype=object), 'TCP_Downlink_Payload_Traffic': array(['2606', '3335'], dtype=object), 'PAGE_SUCCEED_FLAG': array([nan, nan]), 'PAGE_SR_SUCCEED_FLAG': array([None, None], dtype=object), 'SP': array(['Unknown', 'Unknown'], dtype=object), 'FIRSTDNSSUCFLAG': array([0, 0], dtype=int32), 'UFDR_Type': array([None, None], dtype=object), 'DL_TRANS_DELAY': array(['486', '563'], dtype=object), 'UL_TRANS_DELAY': array(['551', '161'], dtype=object), 'AVG_UL_RTT_MICRO_SEC': array(['732', '322'], dtype=object), 'AVG_DW_RTT_MICRO_SEC': array(['902', '566'], dtype=object), 'ERROR_CODE_4xx_TIMES': array([nan, nan]), 'ERROR_CODE_5xx_TIMES': array([nan, nan]), 'GET_TIMEOUT_NUM': array([nan, nan]), 'POST_TO_NUM': array([nan, nan]), 'Flag': array([0, 0], dtype=int32), 'RECORD_DATE_TEHRAN': array(['2025-08-11T19:27:05.000000000', '2025-08-11T19:36:25.000000000'],
#       dtype='datetime64[ns]')}
# (_explorative_take_batch pid=2461) ✔️  Dataset dataset_9_0 execution finished in 10.42 seconds

# %%
# sdk.explorative_take_batch("s3://mybucket/data-delta/", 2)
# sdk.explorative_take_batch(sdk.read_data("s3://mybucket/data-delta/"), 2)
import ray
# print(ray.get(sdk.explorative_take_batch.remote("s3://mybucket/data-delta/", 2)))

# %%
# No 'import' needed! It's already loaded.
from my_platform_sdk import sdk
files = sdk.get_project_files()
print(files)
# Out:
# Listing project files...
# ['subfolder-2', 'mohamadsNotebook.ipynb', 'example1.dash', 'test.ipynb', 'yhg.ipynb', 'renderer.ipynb', 'salam.ipynb', 'README.md', 'train_test.ipynb', 'ipywidgets.ipynb', 'newModel.ipynb', 'xbox.ipynb', 'tmp.ipynb', 'example1.ipynb', 'panel.ipynb', 'collaboration.ipynb', 'MLflow_Tracking_URI', 'somethingggggg (Copy).ipynb', 'someOtherThingsOrNameOrSomethingElseOrChiz.ipynb', 'subfolder-1', 'ping.ipynb', 'matplotlib.ipynb']

# %%
import ray
from typing import Callable, Dict, Iterator, Union
import pyarrow
import pandas
import numpy
ctx = ray.data.DataContext.get_current()
ctx.execution_options.preserve_order = True
import deltalake
RANDOM_SEED = 42
DATA_DEFAULT_BATCH_SIZE = 64

def read_delta(delta_path:str):
    ds = ray.data.read_delta(delta_path)
    return ds
    
def preprocess_ds(ds:ray.data.Dataset, fn: Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]] | Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], Iterator[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]]]):
    ds = ds.map_batches(fn)
    return ds


def read_data_internal(delta_path:str, preprocess_func:Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]] | Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], Iterator[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]]]=None):
    ds = read_delta(delta_path)

    if preprocess_func:
        ds = preprocess_ds(ds, preprocess_func)

    return ds

## user facing function
def _read_data(delta_path:str, preprocess_func:Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]] | Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], Iterator[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]]]=None):
    return read_data_internal(delta_path, preprocess_func)

# ## user facing function
# @ray.remote
# def _explorative_take_batch(ds:ray.data.Dataset, batch_size: int = DATA_DEFAULT_BATCH_SIZE, *, batch_format: str | None = 'default'):
#     return ds.take_batch(batch_size=batch_size, batch_format=batch_format)

## user facing function
@ray.remote
def _explorative_take_batch(delta_path:str, batch_size: int = DATA_DEFAULT_BATCH_SIZE, *, batch_format: str | None = 'default'):
    ds = ray.data.read_delta(delta_path)
    return ds.take_batch(batch_size=batch_size, batch_format=batch_format)

## user facing function
def _explorative_iter_batches(ds:ray.data.Dataset, batch_size: int = DATA_DEFAULT_BATCH_SIZE, *, batch_format: str | None = 'default'):
    return ds.iter_batches(batch_size=batch_size, batch_format=batch_format, local_shuffle_seed=RANDOM_SEED)
# print(_read_data("s3://mybucket/data-delta/"))
print(ray.get(_explorative_take_batch.remote("s3://mybucket/data-delta/", 2)))
# Out:
# (_explorative_take_batch pid=720) Estimated parquet encoding ratio is 6.463.
# (_explorative_take_batch pid=720) Estimated parquet reader batch size at 163881 rows
# (_explorative_take_batch pid=720) A new progress UI is available. To enable, set `ray.data.DataContext.get_current().enable_rich_progress_bars = True`.
# (_explorative_take_batch pid=720) Registered dataset logger for dataset dataset_9_0
# (_explorative_take_batch pid=720) Starting execution of Dataset dataset_9_0. Full logs are in /tmp/ray/session_2025-11-15_08-18-32_003437_7/logs/ray-data
# (_explorative_take_batch pid=720) Execution plan of Dataset dataset_9_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadParquet] -> LimitOperator[limit=2]
# (_explorative_take_batch pid=720) ⚠️  Ray's object store is configured to use only 42.9% of available memory (11.2GiB out of 26.1GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable.
# {'Table_id': array([3101, 3101], dtype=int32), 'Session_ID': array([1305130618271289494, 1305130623311911163]), 'Interface_ID': array([1, 1], dtype=int32), 'Session_Indicator': array([2, 1], dtype=int32), 'Start_Time_s': array([1754927850, 1754928354]), 'Start_Time_ms': array([ 64, 399], dtype=int32), 'End_Time_s': array([1754927851, 1754928355]), 'End_Time_ms': array([ 67, 769], dtype=int32), 'Protocol_Category': array([4, 4], dtype=int32), 'Protocol': array([48000, 48000], dtype=int32), 'Layer_7_Bearer_Protocol': array([0, 0], dtype=int32), 'MSISDN': array([nan, nan]), 'IMSI': array([nan, nan]), 'IMEI': array([nan, nan]), 'Roaming_Type': array([nan, nan]), 'Roaming_Direction': array([nan, nan]), 'MS_IP_Address': array(['102.184.186.42', '100.66.52.252'], dtype=object), 'Server_IP_Address': array(['212.23.201.122', '17.156.128.11'], dtype=object), 'MS_Port': array([63273, 61290], dtype=int32), 'Server_Port': array([3001,  443], dtype=int32), 'APN': array([None, None], dtype=object), 'SGSN_Signaling_Plane_IP_Address': array([None, None], dtype=object), 'GGSN_Signaling_Plane_IP_Address': array([None, None], dtype=object), 'SGSN_User_Plane_IP_Address': array([None, None], dtype=object), 'GGSN_User_Plane_IP_Address': array(['10.155.69.67', '10.155.65.21'], dtype=object), 'MCC': array([None, None], dtype=object), 'MNC': array([None, None], dtype=object), 'RAT': array([1, 1], dtype=int32), 'LAC': array([None, None], dtype=object), 'RAC': array([None, None], dtype=object), 'SAC': array([None, None], dtype=object), 'CI': array([None, None], dtype=object), 'Browser_Type': array([nan, nan]), 'Uplink_Traffic': array([  663, 11583]), 'Downlink_Traffic': array([  200, 10949]), 'Network_Uplink_Traffic': array([ 1011, 12771]), 'Network_Downlink_Traffic': array([  416, 12083]), 'Uplink_Packets': array([ 6, 22], dtype=int32), 'Downlink_Packets': array([ 4, 21], dtype=int32), 'TCP_Connection_Status': array([0, 0], dtype=int32), 'TCP_Connection_Release_Status': array([nan, nan]), 'TCP_Connect_RTT_ms': array([12, 12]), 'TCP_Uplink_Out_of_Order_Packets': array([0, 0], dtype=int32), 'TCP_Downlink_Out_of_Order_Packets': array([0, 1], dtype=int32), 'TCP_Uplink_Retransmitted_Packets': array([1, 0], dtype=int32), 'TCP_Downlink_Retransmitted_Packets': array([1, 0], dtype=int32), 'SYN_ACK_Failures_During_TCP_Handshakes': array([0, 0], dtype=int32), 'ACK_Failures_During_TCP_Handshakes': array([0, 0], dtype=int32), 'Host_Name': array([None, 'inappcheck.itunes.apple.com'], dtype=object), 'First_URI_Visited': array(['/api/v1/device-logs', 'inappcheck.itunes.apple.com'], dtype=object), 'Transaction_Type': array([ 3., nan]), 'First_GET_Success_or_Failure_Flag': array([nan, nan]), 'First_GET_Transaction_Failure_Cause_Code': array([nan, nan]), 'First_GET_Response_Delay': array([nan, nan]), 'GET_Transactions': array([nan, nan]), 'Successful_GET_Transactions': array([nan, nan]), 'POST_Transactions': array([nan, nan]), 'Successful_POST_Transactions': array([nan, nan]), 'Page_Browsing_Delay': array([nan, nan]), 'TAC': array([None, None], dtype=object), 'ECI': array([None, None], dtype=object), 'TCP_RTT_of_Step_1_ms': array([3, 2], dtype=int32), 'TCP_Uplink_Retransmitted_Packets_with_Payload': array([0, 0], dtype=int32), 'TCP_Downlink_Retransmitted_Packets_with_Payload': array([0, 0], dtype=int32), 'TCP_Uplink_Packets_with_Payload': array([ 1, 12], dtype=int32), 'TCP_Downlink_Packets_with_Payload': array([ 0, 11], dtype=int32), 'RAN_NE_User_Plane_IP_Address': array(['10.155.65.32', '10.1.129.152'], dtype=object), 'First_DNS_Response_Delay_Within_Page_ms': array([383., 970.]), 'First_DNS_Response_Code_Within_Page': array([0, 0], dtype=int32), 'Page_Size': array([ 761, 4447], dtype=int32), 'First_Page_Response_Delay_ms': array([nan, nan]), 'MCC_of_Home_Carrier': array([None, None], dtype=object), 'MNC_of_Home_Carrier': array([None, None], dtype=object), 'User_Agent': array([None, None], dtype=object), 'Uplink_Valid_Data_Transmission_Duration': array([ 1., 44.]), 'Down ...
#       dtype='datetime64[ns]')}
# (_explorative_take_batch pid=720) ✔️  Dataset dataset_9_0 execution finished in 5.62 seconds

# %%
""" This is a simple LinearRegression model training code for
testing our mlflow server, this code was generated by AI. """

import mlflow
import pandas as pd
from sqlalchemy import create_engine
from sklearn.linear_model import LinearRegression

MLFLOW_TRACKING_URI = "http://127.0.0.1:5001"
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

EXPERIMENT_NAME = "MyMLOpsProject_V5"
ARTIFACT_PATH = "file:///home/mohamad/Desktop/mlops_platform/my_mlflow_data"

try:
    experiment_id = mlflow.create_experiment(
        name=EXPERIMENT_NAME, 
        artifact_location=ARTIFACT_PATH
    )
except mlflow.exceptions.MlflowException as e:
    experiment_id = mlflow.get_experiment_by_name(EXPERIMENT_NAME).experiment_id

mlflow.set_experiment(experiment_id=experiment_id)

DB_URL = "postgresql://mlflow_user:mlflow_pass@localhost:5432/app_data"

def get_data_from_db():
    print(f"Connecting to DB at {DB_URL}...")
    try:
        engine = create_engine(DB_URL)
        query = "SELECT feature_1, feature_2, target FROM model_data"
        df = pd.read_sql(query, engine)
        print("Data loaded successfully from Postgres:")
        print(df.head())
        return df
    except Exception as e:
        print(f"Error connecting to DB or fetching data: {e}")
        return None

def train_model(df):
    print("Starting model training...")

    with mlflow.start_run() as run:
        X = df[['feature_1', 'feature_2']]
        y = df['target']

        n_estimators = 10
        mlflow.log_param("n_estimators", n_estimators)

        model = LinearRegression()
        model.fit(X, y)

        score = model.score(X, y)
        print(f"Model Score (R2): {score}")

        mlflow.log_metric("r2_score", score)

        mlflow.sklearn.log_model(
            sk_model=model,
            artifact_path="model_artifacts",
            registered_model_name="ANewModel"
        )

        print(f"Model logged successfully with run ID: {run.info.run_id}")
        print(f"View this run in MLflow UI: {MLFLOW_TRACKING_URI}/#/experiments/{run.info.experiment_id}/runs/{run.info.run_id}")

data = get_data_from_db()
if data is not None:
    train_model(data)

# %%
from my_platform_sdk import sdk

# This works perfectly:
sdk.read("my-data")
sdk.write("my-predictions")
# Out:
# --- [MLOps Platform SDK] ---
# SDK successfully loaded!
# MLflow Tracking Server: http://mlflow-server:5000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from my_platform_sdk import sdk
#       3 # This works perfectly:
#       4 sdk.read("my-data")
#
# File /app/my_platform_sdk/__init__.py:95
#      92     ds = ray.data.read_delta(delta_path)
#      93     return ds
# ---> 95 def preprocess_ds(ds:ray.data.Dataset, fn: Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]] | Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], Iterator[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]]]):
#      96     ds = ds.map_batches(fn)
#      97     return ds
#
# TypeError: unsupported operand type(s) for |: 'type' and 'type'

# %%
def _read(name):
    print("I'm trying to hack the read function!")

try:
    sdk.read = my_new_read
except AttributeError as e:
    print(f"Failed: {e}")
# Out:
# Failed: Cannot overwrite SDK attribute 'read'. The platform SDK is read-only.

# %%
sdk.read(12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sdk.read(12)
#
# NameError: name 'sdk' is not defined

# %%
from my_platform_sdk import sdk

# This works perfectly:
sdk.read_data("my-data")
# Out:
# --- [MLOps Platform SDK] ---
# SDK successfully loaded!
# MLflow Tracking Server: http://mlflow-server:5000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from my_platform_sdk import sdk
#       3 # This works perfectly:
#       4 sdk.read_data("my-data")
#
# File /app/my_platform_sdk/__init__.py:95
#      92     ds = ray.data.read_delta(delta_path)
#      93     return ds
# ---> 95 def preprocess_ds(ds:ray.data.Dataset, fn: Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]] | Callable[[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]], Iterator[pyarrow.Table | pandas.DataFrame | Dict[str, numpy.ndarray]]]):
#      96     ds = ds.map_batches(fn)
#      97     return ds
#
# TypeError: unsupported operand type(s) for |: 'type' and 'type'

# %%
sdk.read("something_data_data_data")
# Out:
# Now we are able to read data from datasource something_data_data_data the data which we need!
# 'fetch data of something_data_data_data'

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

# --- Train a scikit-learn model ---
X, y = load_iris(return_X_y=True)
sklearn_model = RandomForestClassifier().fit(X, y)

my_custom_tags = {
    "tag": 0.98,
    "model_type": "RandomForest"
}
sdk.start_run("ANEWRUN")
sdk.register_model(sklearn_model, "MyModel", tags=my_custom_tags)
sdk.end_run()
# Out:
# --- [SDK] Finding notebook path to set experiment...
# --- [SDK] Automatically setting experiment to: 'salam.ipynb' ---
# 2025/11/16 06:07:42 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh(<full-path-to-git-executable>)
#
# All git commands will error until this is rectified.
#
# This initial message can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|silent|none|n|0: for no message or exception
#     - warn|w|warning|log|l|1: for a warning message (logging level CRITICAL, displayed by default)
#     - error|e|exception|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
#
# 2025/11/16 06:07:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# --- [SDK] Starting run: ANEWRUN (ID: 1a64ff44ac2b420a99ec7fd760d4dab3) ---
# Attempting to register model MyModel.
# Detected scikit-learn model.
# 2025/11/16 06:07:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'MyModel' already exists. Creating a new version of this model...
# 2025/11/16 06:07:48 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: MyModel, version 11
# Created version '11' of model 'MyModel'.
# --- [SDK] Manually ending run: ANEWRUN ---
# 🏃 View run ANEWRUN at: http://mlflow-server:5000/#/experiments/62/runs/1a64ff44ac2b420a99ec7fd760d4dab3
# 🧪 View experiment at: http://mlflow-server:5000/#/experiments/62

# %%
def register_model(name):
    return name

# %%
register_model
# Out:
# <function __main__.register_model(name)>

# %%
try:
    sdk.register_model = register_model
except AttributeError as e:
    print(f"Failed: {e}")
# Out:
# Failed: Cannot overwrite SDK attribute 'register_model'. The platform SDK is read-only.

# %%
jjk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 jjk
#
# NameError: name 'jjk' is not defined

# %%
print("afshkasf")
# Out:
# afshkasf

# %%
import ray

delta_path = "s3://mybucket/data-delta/"

print(f"Reading batch of 2 from {delta_path}...")
batch_to_write = ray.get(sdk.explorative_take_batch.remote(delta_path, batch_format="pandas"))
print("...Read complete.")
print(batch_to_write)

print(f"Initiating writer for {delta_path} in 'append' mode...")
writer_actor = sdk.initiate_data_writer(delta_path, mode="append")
print("...Writer initiated.")

print(f"Writing batch back to {delta_path}...")
write_future = sdk.write_data(writer_actor, batch_to_write)
ray.get(write_future)  # <- now valid
print("...Write complete!")
# Out:
# Reading batch of 2 from s3://mybucket/data-delta/...
# (_explorative_take_batch pid=720) Estimated parquet encoding ratio is 6.463.
# (_explorative_take_batch pid=720) Estimated parquet reader batch size at 163881 rows
# (_explorative_take_batch pid=720) A new progress UI is available. To enable, set `ray.data.DataContext.get_current().enable_rich_progress_bars = True`.
# (_explorative_take_batch pid=720) Registered dataset logger for dataset dataset_1_0
# (_explorative_take_batch pid=720) Starting execution of Dataset dataset_1_0. Full logs are in /tmp/ray/session_2025-11-16_00-50-22_772210_7/logs/ray-data
# (_explorative_take_batch pid=720) Execution plan of Dataset dataset_1_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadParquet] -> LimitOperator[limit=2]
# (_explorative_take_batch pid=720) ⚠️  Ray's object store is configured to use only 42.9% of available memory (11.2GiB out of 26.1GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable.
# ...Read complete.
# {'Table_id': array([3101, 3101], dtype=int32), 'Session_ID': array([1305130618271289494, 1305130623311911163]), 'Interface_ID': array([1, 1], dtype=int32), 'Session_Indicator': array([2, 1], dtype=int32), 'Start_Time_s': array([1754927850, 1754928354]), 'Start_Time_ms': array([ 64, 399], dtype=int32), 'End_Time_s': array([1754927851, 1754928355]), 'End_Time_ms': array([ 67, 769], dtype=int32), 'Protocol_Category': array([4, 4], dtype=int32), 'Protocol': array([48000, 48000], dtype=int32), 'Layer_7_Bearer_Protocol': array([0, 0], dtype=int32), 'MSISDN': array([nan, nan]), 'IMSI': array([nan, nan]), 'IMEI': array([nan, nan]), 'Roaming_Type': array([nan, nan]), 'Roaming_Direction': array([nan, nan]), 'MS_IP_Address': array(['102.184.186.42', '100.66.52.252'], dtype=object), 'Server_IP_Address': array(['212.23.201.122', '17.156.128.11'], dtype=object), 'MS_Port': array([63273, 61290], dtype=int32), 'Server_Port': array([3001,  443], dtype=int32), 'APN': array([None, None], dtype=object), 'SGSN_Signaling_Plane_IP_Address': array([None, None], dtype=object), 'GGSN_Signaling_Plane_IP_Address': array([None, None], dtype=object), 'SGSN_User_Plane_IP_Address': array([None, None], dtype=object), 'GGSN_User_Plane_IP_Address': array(['10.155.69.67', '10.155.65.21'], dtype=object), 'MCC': array([None, None], dtype=object), 'MNC': array([None, None], dtype=object), 'RAT': array([1, 1], dtype=int32), 'LAC': array([None, None], dtype=object), 'RAC': array([None, None], dtype=object), 'SAC': array([None, None], dtype=object), 'CI': array([None, None], dtype=object), 'Browser_Type': array([nan, nan]), 'Uplink_Traffic': array([  663, 11583]), 'Downlink_Traffic': array([  200, 10949]), 'Network_Uplink_Traffic': array([ 1011, 12771]), 'Network_Downlink_Traffic': array([  416, 12083]), 'Uplink_Packets': array([ 6, 22], dtype=int32), 'Downlink_Packets': array([ 4, 21], dtype=int32), 'TCP_Connection_Status': array([0, 0], dtype=int32), 'TCP_Connection_Release_Status': array([nan, nan]), 'TCP_Connect_RTT_ms': array([12, 12]), 'TCP_Uplink_Out_of_Order_Packets': array([0, 0], dtype=int32), 'TCP_Downlink_Out_of_Order_Packets': array([0, 1], dtype=int32), 'TCP_Uplink_Retransmitted_Packets': array([1, 0], dtype=int32), 'TCP_Downlink_Retransmitted_Packets': array([1, 0], dtype=int32), 'SYN_ACK_Failures_During_TCP_Handshakes': array([0, 0], dtype=int32), 'ACK_Failures_During_TCP_Handshakes': array([0, 0], dtype=int32), 'Host_Name': array([None, 'inappcheck.itunes.apple.com'], dtype=object), 'First_URI_Visited': array(['/api/v1/device-logs', 'inappcheck.itunes.apple.com'], dtype=object), 'Transaction_Type': array([ 3., nan]), 'First_GET_Success_or_Failure_Flag': array([nan, nan]), 'First_GET_Transaction_Failure_Cause_Code': array([nan, nan]), 'First_GET_Response_Delay': array([nan, nan]), 'GET_Transactions': array([nan, nan]), 'Successful_GET_Transactions': array([nan, nan]), 'POST_Transactions': array([nan, nan]), 'Successful_POST_Transactions': array([nan, nan]), 'Page_Browsing_Delay': array([nan, nan]), 'TAC': array([None, None], dtype=object), 'ECI': array([None, None], dtype=object), 'TCP_RTT_of_Step_1_ms': array([3, 2], dtype=int32), 'TCP_Uplink_Retransmitted_Packets_with_Payload': array([0, 0], dtype=int32), 'TCP_Downlink_Retransmitted_Packets_with_Payload': array([0, 0], dtype=int32), 'TCP_Uplink_Packets_with_Payload': array([ 1, 12], dtype=int32), 'TCP_Downlink_Packets_with_Payload': array([ 0, 11], dtype=int32), 'RAN_NE_User_Plane_IP_Address': array(['10.155.65.32', '10.1.129.152'], dtype=object), 'First_DNS_Response_Delay_Within_Page_ms': array([383., 970.]), 'First_DNS_Response_Code_Within_Page': array([0, 0], dtype=int32), 'Page_Size': array([ 761, 4447], dtype=int32), 'First_Page_Response_Delay_ms': array([nan, nan]), 'MCC_of_Home_Carrier': array([None, None], dtype=object), 'MNC_of_Home_Carrier': array([None, None], dtype=object), 'User_Agent': array([None, None], dtype=object), 'Uplink_Valid_Data_Transmission_Duration': array([ 1., 44.]), 'Down ...
#       dtype='datetime64[ns]')}
# Initiating writer for s3://mybucket/data-delta/ in 'append' mode...
# ...Writer initiated.
# Writing batch back to s3://mybucket/data-delta/...
# (_explorative_take_batch pid=720) ✔️  Dataset dataset_1_0 execution finished in 3.69 seconds
# ---------------------------------------------------------------------------
# RayTaskError(ValueError)                  Traceback (most recent call last)
# Cell In[1], line 16
#      14 print(f"Writing batch back to {delta_path}...")
#      15 write_future = sdk.write_data(writer_actor, batch_to_write)
# ---> 16 ray.get(write_future)  # <- now valid
#      17 print("...Write complete!")
#
# File /usr/local/lib/python3.12/site-packages/ray/_private/auto_init_hook.py:22, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      19 @wraps(fn)
#      20 def auto_init_wrapper(*args, **kwargs):
#      21     auto_init_ray()
# ---> 22     return fn(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#      99 if client_mode_should_convert():
#     100     # Legacy code
#     101     # we only convert init function if RAY_CLIENT_MODE=1
#     102     if func.__name__ != "init" or is_client_mode_enabled_by_default:
# --> 103         return getattr(ray, func.__name__)(*args, **kwargs)
#     104 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/ray/util/client/api.py:42, in _ClientAPI.get(self, vals, timeout)
#      35 def get(self, vals, *, timeout=None):
#      36     """get is the hook stub passed on to replace `ray.get`
#      37
#      38     Args:
#      39         vals: [Client]ObjectRef or list of these refs to retrieve.
#      40         timeout: Optional timeout in milliseconds
#      41     """
# ---> 42     return self.worker.get(vals, timeout=timeout)
#
# File /usr/local/lib/python3.12/site-packages/ray/util/client/worker.py:433, in Worker.get(self, vals, timeout)
#     431     op_timeout = max_blocking_operation_time
#     432 try:
# --> 433     res = self._get(to_get, op_timeout)
#     434     break
#     435 except GetTimeoutError:
#
# File /usr/local/lib/python3.12/site-packages/ray/util/client/worker.py:461, in Worker._get(self, ref, timeout)
#     459         logger.exception("Failed to deserialize {}".format(chunk.error))
#     460         raise
# --> 461     raise err
#     462 if chunk.total_size > OBJECT_TRANSFER_WARNING_SIZE and log_once(
#     463     "client_object_transfer_size_warning"
#     464 ):
#     465     size_gb = chunk.total_size / 2**30
#
# RayTaskError(ValueError): ray::DeltaWriter.write_batch() (pid=723, ip=172.19.0.3, actor_id=884d5546c90205e2f74544ed01000000, repr=<my_platform_sdk.DeltaWriter object at 0x7c2c413b3650>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/app/my_platform_sdk/__init__.py", line 144, in write_batch
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/app/my_platform_sdk/__init__.py", line 131, in _init_table_if_needed
#   File "/home/ray/anaconda3/lib/python3.12/site-packages/deltalake/writer/writer.py", line 120, in write_deltalake
#     data = RecordBatchReader.from_arrow(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: Expected object with __arrow_c_array__ or __arrow_c_stream__ method

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pickle --version
#
# NameError: name 'pickle' is not defined
